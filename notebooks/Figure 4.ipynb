# %% [markdown]
# ## Notebook to produce Figure 4 for PPP (protein preference photometry) publication

# %% [markdown]
# ![PPP_figs_R1_09_Fig4.png](attachment:PPP_figs_R1_09_Fig4.png)

# %%
import sys
sys.path.append('..\\helperfx')

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.lines as mlines
import matplotlib.transforms as transforms

import dabest as db
import pandas as pd
import trompy as tp

from settings4figs import *
from fx4figs import *

# %matplotlib inline

# %%
#Adds control column for calculating vs. 50%
con = [0.5] * 15
df_behav.insert(0, "control", con)

#Initializes details for saving statistics
stats_args = {}
stats_args["file"] = "..\\stats\\estimation_stats.xlsx"
stats_args["file"] = "" # Comment this line out to write a new stats file

# with pd.ExcelWriter(stats_args["file"]) as writer:
#     df_behav["control"].to_excel(writer, sheet_name="front")

# %% [markdown]
# ### Panel 4B - forced choice licks for NR to PR rats (Pref Test 2)

# %%
keys = ["pref2_malt_forced", "pref2_cas_forced"]
stats_args["sheet"] = "pref2_forced_licks_nr"
data, df = prep4estimationstats_1group(df_behav, ["NR"], keys)
fig4B = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="Licks (forced)", stats_args=stats_args)
# Out:
# No stats file to write to.

# %% [markdown]
# ### Panel 4C - latencies for NR to PR rats (Pref Test 2)

# %%
keys = ["pref2_malt_lats_fromsip", "pref2_cas_lats_fromsip"]
stats_args["sheet"] = "pref2_latency_nr"
data, df = prep4estimationstats_1group(df_photo, ["NR"], keys)
fig4C = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="Latency (s)", stats_args=stats_args)
# Out:
# No stats file to write to.

# %% [markdown]
# ### Panel 4D - free choice licks for NR to PR rats (Pref Test 2)

# %%
keys = ["pref2_malt_free", "pref2_cas_free"]
stats_args["sheet"] = "pref2_free_licks_nr"
data, df = prep4estimationstats_1group(df_behav, ["NR"], keys)
fig4D = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="Licks (free)", stats_args=stats_args)
# Out:
# No stats file to write to.

# %% [markdown]
# ### Panel 4E - average photometry signal (Pref Test 2)

# %%
keys = ['pref2_cas_licks_forced', 'pref2_malt_licks_forced']
fig4E = photogroup_panel(df_photo, keys, "NR", colorgroup="expt")

# %% [markdown]
# ### Panel 4F - AUC for NR to PR rats (Pref Test 2)

# %%
keys = ["pref2_auc_malt", "pref2_auc_cas"]
stats_args["sheet"] = "pref2_auc_nr"
data, df = prep4estimationstats_1group(df_photo, ["NR"], keys)
fig4F = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="AUC", stats_args=stats_args)
# Out:
# No stats file to write to.

# %% [markdown]
# ### Panel 4H - forced choice licks for NR to PR rats (Pref Test 3)

# %%
keys = ["pref3_malt_forced", "pref3_cas_forced", ]
stats_args["sheet"] = "pref3_forced_licks_nr"
data, df = prep4estimationstats_1group(df_behav, ["NR"], keys)
fig4H = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="Licks (forced)", stats_args=stats_args)
# Out:
# No stats file to write to.

# %% [markdown]
# ### Panel 4I - latencies for NR to PR rats (Pref Test 3)

# %%
keys = ["pref3_malt_lats_fromsip", "pref3_cas_lats_fromsip"]
stats_args["sheet"] = "pref3_latency_nr"
data, df = prep4estimationstats_1group(df_photo, ["NR"], keys)
fig4I = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="Latency (s)", stats_args=stats_args)
# Out:
# No stats file to write to.

# %% [markdown]
# ### Panel 4J - free choice licks for NR to PR rats (Pref Test 3)

# %%
keys = ["pref3_malt_free", "pref3_cas_free", ]
stats_args["sheet"] = "pref3_free_licks_nr"
data, df = prep4estimationstats_1group(df_behav, ["NR"], keys)
fig4J = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="Licks (free)", stats_args=stats_args)
# Out:
# No stats file to write to.

# %% [markdown]
# ### Panel 4K - average photometry signal (Pref Test 3)

# %%
keys = ['pref3_cas_licks_forced', 'pref3_malt_licks_forced']
fig4K = photogroup_panel(df_photo, keys, "NR", colorgroup="expt")

# %% [markdown]
# ### Panel 4L - AUC for NR to PR rats (Pref Test 3)

# %%
keys = ["pref3_auc_malt", "pref3_auc_cas", ]
stats_args["sheet"] = "pref3_auc_nr"
data, df = prep4estimationstats_1group(df_photo, ["NR"], keys)
fig4L = barscatter_plus_estimation_1group(data, df, colors="expt", ylabel="AUC", stats_args=stats_args)
# Out:
# No stats file to write to.
