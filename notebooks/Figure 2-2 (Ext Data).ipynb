# %% [markdown]
# ## Notebook to produce Figure 2-2 Extended Data - late AUC (5 seconds following termination of licking)

# %% [markdown]
# ### Extended Data 2-2

# %% [markdown]
# ![PPP_supplemental_figs_R1_Fig%202-2.png](attachment:PPP_supplemental_figs_R1_Fig%202-2.png)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.lines as mlines
import matplotlib.transforms as transforms

import dabest as db
import pandas as pd

import trompy as tp

from ppp_pub_figs_settings import *
from ppp_pub_figs_fx import *

# %matplotlib inline

# %%
stats_args = {}
stats_args["file"] = "C:\\Github\\PPP_analysis\\stats\\estimation_stats.xlsx"
stats_args["file"] = "" # Comment this line out to write a new stats file

# %%
keys =  ['pref1_lateauc_malt', 'pref1_lateauc_cas']
stats_args["sheet"] = "pref1_lateauc"
data, df = prep4estimationstats(df_photo, ["NR", "PR"], keys)
fig2_2 = barscatter_plus_estimation(data, df, ylabel="Late AUC (5-10 s)", stats_args=stats_args)
# Out:
# No stats file to write to.
