# %% [markdown]
# ## Notebook to produce Figure 2-1 Extended Data - behavioral tracking for PPP (protein preference photometry) publication

# %% [markdown]
# ### Extended Data 2-1

# %% [markdown]
# ![PPP_supplemental_figs_R1_Fig%202-1.png](attachment:PPP_supplemental_figs_R1_Fig%202-1.png)

# %% [markdown]
# Tracking of rats was pefformed using DeepLabCut. Scripts including configuration files etc are contained in the "videos" subfolder of the main directory.
